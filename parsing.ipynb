# %% [markdown]
# <a href="https://colab.research.google.com/github/TipoYmnik/Data-analysis-in-Python.-/blob/main/parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Подгрузим необходимые библиотеки
import requests
from time import sleep
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Парсинг

# %% [markdown]
# Работа с API сайта <a target="_blank" href="hh.ru">hh.ru</a>. Документация доступна по <a target="_blank" href="https://github.com/hhru/api/blob/master/docs/vacancies.md#search">ссылке</a>.

# %% [markdown]
# **Задача:**
# 1. выберем 5 не смежныъ профессий.
# 2. затем получим доступные по данным профессиям вакансии в Москве и выделим их физические координаты.
# 3. Отберем вакансии в пределах МКАД, нанесем полученные координаты на карту местоположения компаний.

# %%
URL = 'https://api.hh.ru/vacancies'
jobs = ['Тестировщик', 'Инженер', 'Графический дизайнер', 'Преподаватель английского языка', 'Аналитик']
data = []
vacancy_counters = []
for vacancy in jobs:
    req = requests.get(URL,
                       {'text': vacancy, 'area': 1, 'page': 0, 'per_page': 100 })
    if req.status_code != 200:
        continue
    df = pd.json_normalize(req.json()['items'])
    df['vacancy'] = vacancy
    data.append(df)
    vacancy_counters.append(req.json()['found'])
    for i in range(1, req.json()['pages']):
        req = requests.get(URL,
                           {'text': vacancy, 'area': 1, 'page': i, 'per_page': 100 })
        if req.status_code != 200:
            continue
        df = pd.json_normalize(req.json()['items'])
        df['vacancy'] = vacancy
        data.append(df)

data = pd.concat(data, ignore_index = True)
data.head()
# Out:
#           id  premium                          name  has_test  \
# 0  107313304    False                   QA Engineer     False
# 1  105135924    False          Frontend-разработчик     False
# 2  106353373    False  Frontend разработчик (React)     False
# 3  107342971    False                Qa-тестировщик     False
# 4  107336573    False    Специалист по тестированию     False
#
#    response_letter_required  salary  address response_url sort_point_distance  \
# 0                     False     NaN      NaN         None                None
# 1                     False     NaN      NaN         None                None
# 2                     False     NaN      NaN         None                None
# 3                     False     NaN      NaN         None                None
# 4                     False     NaN      NaN         None                None
#
#                published_at  ... address.id  salary.from salary.to  \
# 0  2024-09-16T10:55:52+0300  ...        NaN          NaN       NaN
# 1  2024-09-12T18:28:06+0300  ...     666344          NaN       NaN
# 2  2024-08-26T19:19:49+0300  ...        NaN          NaN       NaN
# 3  2024-09-16T15:48:58+0300  ...        NaN          NaN  150000.0
# 4  2024-09-16T14:47:10+0300  ...        NaN          NaN       NaN
#
#   salary.currency salary.gross employer.logo_urls insider_interview.id  \
# 0             NaN          NaN                NaN                  NaN
# 1             NaN          NaN                NaN                  NaN
# 2             NaN          NaN                NaN                  NaN
# 3             RUR         True                NaN                  NaN
# 4             NaN          NaN                NaN                  NaN
#
#   insider_interview.url address.metro      vacancy
# 0                   NaN           NaN  Тестировщик
# 1                   NaN           NaN  Тестировщик
# 2                   NaN           NaN  Тестировщик
# 3                   NaN           NaN  Тестировщик
# 4                   NaN           NaN  Тестировщик
#
# [5 rows x 80 columns]

# %% [markdown]
# Узнаем сколько всего найдено вакансий:

# %%
pd.DataFrame({'job':jobs, 'count': vacancy_counters})
# Out:
#                                job  count
# 0                      Тестировщик   2553
# 1                          Инженер  23915
# 2             Графический дизайнер   1536
# 3  Преподаватель английского языка    439
# 4                         Аналитик  23559

# %% [markdown]
# Найдем количество пропусков в данных о координатах:

# %%
data['address.lng'].isnull().sum()
# Out:
# 3824

# %%
data['address.lat'].isnull().sum()
# Out:
# 3824

# %% [markdown]
# Очистим данные от пропусков и выберем интересующие нас признаки:

# %%
data = data[['employer.name', 'address.lat','address.lng']]
data = data.dropna()
data.head()
# Out:
#                          employer.name  address.lat  address.lng
# 1                                 edna    55.708421    37.652694
# 8                         АйТи БАСТИОН    55.707791    37.595806
# 11                          Content AI    55.856563    37.599507
# 14  R-Style Softlab (Эр-Стайл Софтлаб)    55.623315    37.511041
# 17                                  T2    55.632925    37.439516

# %% [markdown]
# Найдем количество вакансий, у которых заданы координаты:

# %%
data.shape
# Out:
# (4152, 3)

# %% [markdown]
# </i> у 4142 компаний заданы координаты, те компании , у которых координаты были пустими, очищены на предыдущем шаге. <i>

# %% [markdown]
# Отберем вакансии, которые расположены в пределах МКАД:

# %% [markdown]
# Напишем функцию, которая рассчитывает расстояние между объектами, знаяя их координаты, для каждого объекта найдем его расстояние до Кремля.

# %%
import math

def haversine(lat1, lon1, lat2, lon2):
    # Радиус Земли в километрах
    R = 6371.0

    # Конвертируем координаты из градусов в радианы
    lat1_rad = math.radians(lat1)
    lon1_rad = math.radians(lon1)
    lat2_rad = math.radians(lat2)
    lon2_rad = math.radians(lon2)

    # Разности координат
    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad

    # Формула Хаверсина
    a = math.sin(dlat / 2)**2 + math.cos(lat1_rad) * math.cos(lat2_rad) * math.sin(dlon / 2)**2
    c = 2 * math.asin(math.sqrt(a))

    # Возврат расстояния в километрах
    distance = R * c
    return distance

fixed_lat, fixed_lng = 55.752004, 37.617734 # Координаты кремля


data['distance'] = data.apply(lambda x: haversine(x['address.lat'], x['address.lng'],
                               fixed_lat, fixed_lng),axis = 1)

# %%
# Будем считать, что расстояние от кремля до МКАДа равно 15 км.
data = data[data.distance <= 15]

# %%
data = data.rename(columns = {'employer.name': 'company',
                     'address.lat': 'latitude', 'address.lng' :'longitude' })

# %% [markdown]
# Построим график в координатах "широта-долгота" для отображения вакансий внутри МКАД:

# %%
import plotly.express as px

fig = px.scatter_mapbox(
    data,
    lat='latitude',
    lon='longitude',
    hover_name='company',
    opacity=0.6,
    title='Вакансии внутри МКАД',
    mapbox_style='carto-positron',
    zoom=10,
    height=600
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df9170a9-a85e-47c0-bbdd-24c7a0f3b6ec" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df9170a9-a85e-47c0-bbdd-24c7a0f3b6ec")) {                    Plotly.newPlot(                        "df9170a9-a85e-47c0-bbdd-24c7a0f3b6ec",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["edna","\u0410\u0439\u0422\u0438 \u0411\u0410\u0421\u0422\u0418\u041e\u041d","Content AI","\u0418\u043d\u0444\u043e\u0440\u0443\u0441","RUTUBE","Sape","\u0411\u0418\u0424\u0418\u0422","\u041a\u043e\u0440\u043f\u043e\u0440\u0430\u0446\u0438\u044f \u042d\u041b\u0410\u0420","7\u0442\u0435\u043a","Digital Spirit","\u041f\u041e\u041b\u0415.\u0420\u0424","amoCRM","Radium Finance","\u041f\u0423\u041b\u042c\u0421","AVON","\u0424\u043e\u0440\u0441\u0430\u0439\u0442","netPrint.ru","\u0421\u0418\u0421\u0422\u042d\u041c \u042d\u041b\u0415\u041a\u0422\u0420\u0418\u041a","\u0422\u0440\u0430\u043d\u0441\u043d\u0435\u0444\u0442\u044c-\u0422\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0438","\u041c\u0422\u0421","\u041a\u043e\u043d\u0441\u0438\u0441\u0442-\u041e\u0421","\u0410\u043f\u0442\u0435\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c 36,6","YCLIENTS LLC","\u0424\u043e\u0440\u043c\u0443\u043b\u0430 \u0411\u0438 \u0410\u0439","Bright Pattern, Inc","DSSL","\u0414\u043e\u043a\u0442\u043e\u0440 \u0412\u0435\u0431","\u042d\u043d\u0438\u0433\u043c\u0430 \u0413\u0440\u0443\u043f\u043f","\u0421\u0435\u0440\u0432\u0435\u0440 \u0432 \u0410\u0440\u0435\u043d\u0434\u0443","\u041c\u0435\u0433\u0430\u043f\u043e\u043b\u0438\u0441 \u0418\u0422","\u0420\u0435\u043a\u0443\u0440\u0441\u0438\u044f","IDF Lab","\u0422\u0435\u0445\u0410\u0440\u0433\u043e\u0441","\u0421\u0438\u043d\u0445\u0440\u043e","ADV\u002fweb-engineering","\u041a\u041f\u041b","\u041e\u043d\u043b\u0430\u0439\u043d-\u0448\u043a\u043e\u043b\u0430 \u0422\u0435\u0442\u0440\u0438\u043a\u0430","\u0421\u0431\u0435\u0440\u0421\u043f\u0430\u0441\u0438\u0431\u043e","F.A.C.C.T.","\u0412\u0435\u0431\u043c\u043e\u043d\u0438\u0442\u043e\u0440\u044d\u043a\u0441","Emehanika Tech","\u0410\u043d\u043b\u0438\u043c\u0438\u0442\u0435\u0434 \u041f\u0440\u043e\u0434\u0430\u043a\u0448\u0435\u043d","\u0420\u043e\u043a\u0435\u0442 \u0422\u0435\u0445","\u0422\u0440\u0438 \u0422\u043e\u0447\u043a\u0438","KTS","\u0426\u0435\u043d\u0442\u0440 2\u041c","\u0422\u043e\u0447\u043a\u0430 \u041e\u043f\u043b\u0430\u0442\u044b","\u0421\u043c\u0430\u0440\u0442 \u042d\u043d\u0434\u0436\u0438\u043d\u0441 \u0421\u0435\u0440\u0432\u0438\u0441","\u0410\u043d\u043b\u0438\u043c\u0438\u0442\u0435\u0434 \u041f\u0440\u043e\u0434\u0430\u043a\u0448\u0435\u043d","\u0421\u0442\u0440\u0430\u0445\u043e\u0432\u0430\u044f \u0433\u0440\u0443\u043f\u043f\u0430 \u041c\u0410\u041a\u0421","\u041c\u0422\u0422 (MTC Exolve)","\u042d\u041b\u0415\u041a\u0422\u0420\u041e\u041d\u041d\u042b\u0415 \u041e\u0424\u0418\u0421\u041d\u042b\u0415 \u0421\u0418\u0421\u0422\u0415\u041c\u042b","\u0411\u0415\u0422\u0421\u0418\u0422\u0418","\u041f\u0438\u043a\u043b\u0435\u043c\u0430","\u0410\u0439\u043a\u043e\u043d \u041f\u0440\u043e","\u041a\u0410\u0422\u042e\u0428\u0410 \u041f\u0420\u0418\u041d\u0422","Robusta","\u042d\u043b\u0435\u043a\u0442\u0440\u043e\u043d\u043d\u0430\u044f \u0442\u043e\u0440\u0433\u043e\u0432\u0430\u044f \u043f\u043b\u043e\u0449\u0430\u0434\u043a\u0430 \u0413\u0430\u0437\u043f\u0440\u043e\u043c\u0431\u0430\u043d\u043a\u0430","\u041c\u043e\u0439\u0421\u043a\u043b\u0430\u0434","\u0426\u0435\u043d\u0442\u0440 \u041d\u043e\u0432\u044b\u0445 \u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0445 \u0421\ ...

# %% [markdown]
# **Выводы о проделанной работе:**

# %% [markdown]
# При парсинге данных довольно часто возникают проблемы. Было найдено намного больше вакансий, чем по итогу удалось прочитать. Причем в прочитанных данных было довольно много пропусков. По пулученному в ходе работы графику можно сделать вывод о том, что большинство компаний сконцентрированно в центре.
